# %%
# Financial Data with Python: yfinance
# https://youtu.be/7wAQCwdvqqo

# %%
# !pip install pandas
# !pip install seaborn
# !pip install yfinance
# Out:
# Requirement already satisfied: pandas in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.20.3; python_version < "3.10" in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: seaborn in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: pandas>=1.2 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: cycler>=0.10 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: packaging>=20.0 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: pytz>=2020.1 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib!=3.6.1,>=3.4->seaborn) (3.19.2)
# Requirement already satisfied: six>=1.5 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Collecting yfinance
#   Using cached yfinance-0.2.40-py2.py3-none-any.whl (73 kB)
# Processing /home/mzucker007/.cache/pip/wheels/50/f5/5d/c6bc991ef2e027c2d14113be120f99704e268b48057a90529d/peewee-3.17.5-cp38-cp38-linux_x86_64.whl
# Collecting frozendict>=2.3.4
#   Using cached frozendict-2.4.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (115 kB)
# Collecting lxml>=4.9.1
#   Using cached lxml-5.2.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.0 MB)
# Collecting html5lib>=1.1
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: requests>=2.31 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: numpy>=1.16.5 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from yfinance) (1.24.4)
# Requirement already satisfied: pytz>=2022.5 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: pandas>=1.3.0 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: webencodings in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from requests>=2.31->yfinance) (2024.7.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: soupsieve>1.2 in /home/mzucker007/code/trading/yfinance01/venv/lib/python3.8/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Installing collected packages: peewee, frozendict, lxml, html5lib, multitasking, yfinance
# Successfully installed frozendict-2.4.4 html5lib-1.1 lxml-5.2.2 multitasking-0.0.11 peewee-3.17.5 yfinance-0.2.40

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pit
import yfinance as yf

# %%
## Basic Example

# %%
msft = yf.Ticker("MSFT")

# %%
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and power automate; and on-premises ERP and CRM applications. The Intelligent Cloud segment offers server products and cloud services, such as azure and other cloud services; SQL and windows server, visual studio, system center, and related client access licenses, as well as nuance and GitHub; and enterprise services including enterprise support services, industry solutions, and nuance professional services. The More Personal Computing segment offers Windows, including windows OEM licensing and other non-volume licensing of the Windows operating system; Windows commercial comprising volume licensing of the Windows operating system, windows cloud services, and other Windows commercial offerings; patent licensing; and windows Internet of Things; and devices, such as surface, HoloLens, and PC accessories. Additionally, this segment provides gaming, which includes Xbox hardware and content, and first- and third-party content; Xbox game pass and other subscriptions, cloud gaming, advertising, third-party disc royalties, and other cloud services; and search and news advertising, which includes Bing, Microsoft News and Edge, and third-party affiliates. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online, and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.',
#  'fullTimeEmployees': 221000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Satya  Nadella',
#    'age': 56,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'totalPay': 9276400,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bradford L. Smith LCA',
#    'age': 64,
#    'title': 'President & Vice Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2023,
#    'totalPay': 3591277,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Amy E. Hood',
#    'age': 51,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'totalPay': 3452196,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Judson B. Althoff',
#    'age': 49,
#    'title': 'Executive VP & Chief Commercial Officer',
#    'yearBorn': 1974,
#    'fiscalYear': 2023,
#    'totalPay': 3355797,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Christopher David Young',
#    'age': 51,
#    'title': 'Executive Vice President of Business Development, Strategy & Ventures',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'totalPay': 2460507,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alice L. Jolla',
#    'age': 56,
#    'title': 'Corporate VP & Chief Accounting Officer',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James Kevin Scott',
#    'age': 51,
#    'title': 'Executive VP of AI & CTO',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Brett  Iversen',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hossein  Nowbar',
#    'title': 'Chief Legal Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frank X. Shaw',
#    'title': 'Chief Communications Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 3,
#  'boardRisk': 4,
#  'compensationRisk': 2,
#  'shareHolderRightsRisk': 2,
#  'overallRisk': 1,
#  'governanceEpochDate': 1719792000,
#  'compensationAsOfEpochDate': 1703980800,
#  'irWebsite': 'http://www.microsoft.com/investor/default.aspx',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 460.77,
#  'open': 459.66,
#  'dayLow': 458.965,
#  'dayHigh': 468.35,
#  'regularMarketPreviousClose': 460.77,
#  'regularMarketOpen': 459.66,
#  'regularMarketDayLow': 458.965,
#  'regularMarketDayHigh': 468.35,
#  'dividendRate': 3.0,
#  'dividendYield': 0.0064999997,
#  'exDividendDate': 1723680000,
#  'payoutRatio': 0.24780001,
#  'fiveYearAvgDividendYield': 0.92,
#  'beta': 0.894,
#  'trailingPE': 40.586803,
#  'forwardPE': 37.92052,
#  'volume': 15662166,
#  'regularMarketVolume': 15662166,
#  'averageVolume': 18883259,
#  'averageVolume10days': 18827580,
#  'averageDailyVolume10Day': 18827580,
#  'bid': 467.3,
#  'ask': 467.52,
#  'bidSize': 100,
#  'askSize': 200,
#  'marketCap': 3475050856448,
#  'fiftyTwoWeekLow': 309.45,
#  'fiftyTwoWeekHigh': 468.35,
#  'priceToSalesTrailing12Months': 14.688444,
#  'fiftyDayAverage': 426.0936,
#  'twoHundredDayAverage': 391.43756,
#  'trailingAnnualDividendRate': 2.93,
#  'trailingAnnualDividendYield': 0.006358921,
#  'currency': 'USD',
#  'enterpriseValue': 3501264994304,
#  'profitMargins': 0.36426997,
#  'floatShares': 7422123535,
#  'sharesOutstanding': 7432309760,
#  'sharesShort': 62396959,
#  'sharesShortPriorMonth': 43764126,
#  'sharesShortPreviousMonthDate': 1715731200,
#  'dateShortInterest': 1718323200,
#  'sharesPercentSharesOut': 0.0084,
#  'heldPercentInsiders': 0.00054000004,
#  'heldPercentInstitutions': 0.73624,
#  'shortRatio': 3.41,
#  'shortPercentOfFloat': 0.0084,
#  'impliedSharesOutstanding': 7432309760,
#  'bookValue': 34.058,
#  'priceToBook': 13.728346,
#  'lastFiscalYearEnd': 1688083200,
#  'nextFiscalYearEnd': 1719705600,
#  'mostRecentQuarter': 1711843200,
#  'earningsQuarterlyGrowth': 0.199,
#  'netIncomeToCommon': 86181003264,
#  'trailingEps': 11.52,
#  'forwardEps': 12.33,
#  'pegRatio': 2.8,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1045526400,
#  'enterpriseToRevenue': 14.799,
#  'enterpriseToEbitda': 27.792,
#  '52WeekChange': 0.36637807,
#  'SandP52WeekChange': 0.25871396,
#  'lastDividendValue': 0.75,
#  'lastDividendDate': 1715731200,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'underlyingSymbol': 'MSFT',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'firstTradeDateEpochUtc': 511108200,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': 'b004b3ec-de24-385e-b2c1-923f10d3fb62',
#  'messageBoardId': 'finmb_21835',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 467.56,
#  'targetHighPrice': 555.9,
#  'targetLowPrice': 403.95,
#  'targetMeanPrice': 453.03,
#  'targetMedianPrice': 445.55,
#  'recommendationMean': 1.7,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 46,
#  'totalCash': 80013000704,
#  'totalCashPerShare': 10.766,
#  'ebitda': 125981999104,
#  'totalDebt': 106228998144,
#  'quickRatio': 1.132,
#  'currentRatio': 1.242,
#  'totalRevenue': 236583993344,
#  'debtToEquity': 41.963,
#  'revenuePerShare': 31.834,
#  'returnOnAssets': 0.1541,
#  'returnOnEquity': 0.38487998,
#  'freeCashflow': 61997998080,
#  'operatingCashflow': 110122999808,
#  'earningsGrowth': 0.2,
#  'revenueGrowth': 0.17,
#  'grossMargins': 0.69894,
#  'ebitdaMargins': 0.5325,
#  'operatingMargins': 0.44588003,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.2718}

# %%
hist = msft.history(period="max")

# %%
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-03-13 00:00:00-05:00    0.054693    0.062736    0.054693    0.060055
# 1986-03-14 00:00:00-05:00    0.060055    0.063272    0.060055    0.062199
# 1986-03-17 00:00:00-05:00    0.062199    0.063808    0.062199    0.063272
# 1986-03-18 00:00:00-05:00    0.063272    0.063808    0.061127    0.061663
# 1986-03-19 00:00:00-05:00    0.061663    0.062199    0.060055    0.060591
# ...                               ...         ...         ...         ...
# 2024-06-28 00:00:00-04:00  453.070007  455.380005  446.410004  446.950012
# 2024-07-01 00:00:00-04:00  448.660004  457.369995  445.660004  456.730011
# 2024-07-02 00:00:00-04:00  453.200012  459.589996  453.109985  459.279999
# 2024-07-03 00:00:00-04:00  458.190002  461.019989  457.880005  460.769989
# 2024-07-05 00:00:00-04:00  459.660004  468.350006  458.964996  467.559998
#
#                                Volume  Dividends  Stock Splits
# Date
# 1986-03-13 00:00:00-05:00  1031788800        0.0           0.0
# 1986-03-14 00:00:00-05:00   308160000        0.0           0.0
# 1986-03-17 00:00:00-05:00   133171200        0.0           0.0
# 1986-03-18 00:00:00-05:00    67766400        0.0           0.0
# 1986-03-19 00:00:00-05:00    47894400        0.0           0.0
# ...                               ...        ...           ...
# 2024-06-28 00:00:00-04:00    28362300        0.0           0.0
# 2024-07-01 00:00:00-04:00    17662800        0.0           0.0
# 2024-07-02 00:00:00-04:00    13979800        0.0           0.0
# 2024-07-03 00:00:00-04:00     9932800        0.0           0.0
# 2024-07-05 00:00:00-04:00    15662166        0.0           0.0
#
# [9655 rows x 7 columns]

# %%
msft.actions # dividends or stock splits
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-09-21 00:00:00-04:00       0.00           2.0
# 1990-04-16 00:00:00-04:00       0.00           2.0
# 1991-06-27 00:00:00-04:00       0.00           1.5
# 1992-06-15 00:00:00-04:00       0.00           1.5
# 1994-05-23 00:00:00-04:00       0.00           2.0
# ...                              ...           ...
# 2023-05-17 00:00:00-04:00       0.68           0.0
# 2023-08-16 00:00:00-04:00       0.68           0.0
# 2023-11-15 00:00:00-05:00       0.75           0.0
# 2024-02-14 00:00:00-05:00       0.75           0.0
# 2024-05-15 00:00:00-04:00       0.75           0.0
#
# [91 rows x 2 columns]

# %%
msft.dividends
# Out:
# Date
# 2003-02-19 00:00:00-05:00    0.08
# 2003-10-15 00:00:00-04:00    0.16
# 2004-08-23 00:00:00-04:00    0.08
# 2004-11-15 00:00:00-05:00    3.08
# 2005-02-15 00:00:00-05:00    0.08
#                              ...
# 2023-05-17 00:00:00-04:00    0.68
# 2023-08-16 00:00:00-04:00    0.68
# 2023-11-15 00:00:00-05:00    0.75
# 2024-02-14 00:00:00-05:00    0.75
# 2024-05-15 00:00:00-04:00    0.75
# Name: Dividends, Length: 82, dtype: float64

# %%
msft.major_holders
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.00054
# institutionsPercentHeld          0.73624
# institutionsFloatPercentHeld     0.73664
# institutionsCount             6803.00000

# %%
msft.institutional_holders
# Out:
#   Date Reported                             Holder  pctHeld     Shares  \
# 0    2023-06-30                 Vanguard Group Inc   0.0879  653247546
# 1    2023-06-30                     Blackrock Inc.   0.0722  536245027
# 2    2023-06-30           State Street Corporation   0.0395  293614078
# 3    2023-06-30                           FMR, LLC   0.0283  210111250
# 4    2023-06-30      Price (T.Rowe) Associates Inc   0.0215  159904219
# 5    2023-06-30      Geode Capital Management, LLC   0.0199  148129470
# 6    2023-06-30                     Morgan Stanley   0.0166  123498322
# 7    2023-06-30          JP Morgan Chase & Company   0.0152  113024837
# 8    2022-12-31  Norges Bank Investment Management   0.0116   86316926
# 9    2023-06-30            Capital World Investors   0.0115   85507261
#
#           Value
# 0  222456919314
# 1  182612881494
# 2   99987338122
# 3   71551285075
# 4   54453782738
# 5   50444009713
# 6   42056118573
# 7   38489477991
# 8   20700525193
# 9   29118642660

# %%
msft.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         14   13     6     0           1
# 1    -1m         23   33     3     0           0
# 2    -2m         23   32     3     0           0
# 3    -3m         20   27     6     0           0

# %%
msft.calendar
# Out:
# {'Dividend Date': datetime.date(2024, 9, 11),
#  'Ex-Dividend Date': datetime.date(2024, 8, 14),
#  'Earnings Date': [datetime.date(2024, 7, 23), datetime.date(2024, 7, 29)],
#  'Earnings High': 3.07,
#  'Earnings Low': 2.65,
#  'Earnings Average': 2.72,
#  'Revenue High': 60725600000,
#  'Revenue Low': 59296000000,
#  'Revenue Average': 59618400000}

# %%
hist.plot(kind="line", figsize=(12,12), subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
## Adv. Financial Data Gathering

# %%
# major indices
major_indices = pd.read_html("https://finance.yahoo.com/world-indices")[0]

# %%
major_indices.head()
# Out:
#   Symbol     Name  Last Price  Change % Change  Volume  Intraday High/Low  \
# 0  ^GSPC  S&P 500     5567.19   30.17   +0.54%     NaN                NaN
# 1   ^DJI   Dow 30    39375.87   67.87   +0.17%     NaN                NaN
# 2  ^IXIC   Nasdaq    18352.76  164.46   +0.90%     NaN                NaN
# 3   ^NYA      NaN         NaN     NaN      NaN     NaN                NaN
# 4   ^XAX      NaN         NaN     NaN      NaN     NaN                NaN
#
#    52 Week Range  Day Chart
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN

# %%
ticker_list = major_indices['Symbol'].str.replace("^","").str.lower().to_list()

# %%
ticker_data = yf.Tickers(ticker_list)

# %%
ticker_data
# Out:
# yfinance.Tickers object <GSPC,DJI,IXIC,NYA,XAX,BUK100P,RUT,VIX,FTSE,GDAXI,FCHI,STOXX50E,N100,BFX,IMOEX.ME,N225,HSI,000001.SS,399001.SZ,STI,AXJO,AORD,BSESN,JKSE,KLSE,NZ50,KS11,TWII,GSPTSE,BVSP,MXX,IPSA,MERV,TA125.TA,CASE30,JN0U.JO>

# %%
df = yf.download(ticker_list, period="1d", start="2020-01-13", end="2021-03-10")
# Out:
# [**********************58%%**                    ]  21 of 36 completed
# $MXX: possibly delisted; No price data found  (1d 2020-01-13 -> 2021-03-10)
# [*********************100%%**********************]  36 of 36 completed
#
# 31 Failed downloads:
# ['GDAXI', 'KS11', 'MERV', 'BFX', 'BVSP', 'JKSE', 'BSESN', 'TA125.TA', 'TWII', 'AXJO', 'GSPTSE', 'FCHI', 'FTSE', 'IPSA', 'N225', 'NZ50', 'STOXX50E', 'CASE30', 'N100', 'JN0U.JO', 'BUK100P', 'GSPC', 'IXIC', 'AORD']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ['RUT', 'KLSE', 'NYA', 'XAX', 'VIX']: YFInvalidPeriodError("%ticker%: Period '1d' is invalid, must be one of ['1mo', '3mo', '6mo', 'ytd', '1y', '2y', '5y', '10y', 'max']")
# ['STI']: YFChartError("%ticker%: Data doesn't exist for startDate = 1578891600, endDate = 1615352400")
# ['MXX']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2020-01-13 -> 2021-03-10)')

# %%
len(ticker_list)
# Out:
# 36

# %%
df
# Out:
# Price         Adj Close                                                        \
# Ticker        000001.SS     399001.SZ AORD AXJO BFX BSESN BUK100P BVSP CASE30
# Date
# 2020-01-13  3115.570068  11040.200195  NaN  NaN NaN   NaN     NaN  NaN    NaN
# 2020-01-14  3106.820068  10988.769531  NaN  NaN NaN   NaN     NaN  NaN    NaN
# 2020-01-15  3090.040039  10972.320312  NaN  NaN NaN   NaN     NaN  NaN    NaN
# 2020-01-16  3074.081055  10967.440430  NaN  NaN NaN   NaN     NaN  NaN    NaN
# 2020-01-17  3075.496094  10954.389648  NaN  NaN NaN   NaN     NaN  NaN    NaN
# ...                 ...           ...  ...  ...  ..   ...     ...  ...    ...
# 2021-03-03  3576.899902  14932.389648  NaN  NaN NaN   NaN     NaN  NaN    NaN
# 2021-03-04  3503.489990  14416.059570  NaN  NaN NaN   NaN     NaN  NaN    NaN
# 2021-03-05  3501.987061  14412.309570  NaN  NaN NaN   NaN     NaN  NaN    NaN
# 2021-03-08  3421.409912  13863.809570  NaN  NaN NaN   NaN     NaN  NaN    NaN
# 2021-03-09  3359.290039  13475.719727  NaN  NaN NaN   NaN     NaN  NaN    NaN
#
# Price                     ... Volume                                          \
# Ticker               DJI  ...   N225 NYA NZ50 RUT STI STOXX50E TA125.TA TWII
# Date                      ...
# 2020-01-13  28907.099609  ...    NaN NaN  NaN NaN NaN      NaN      NaN  NaN
# 2020-01-14  28939.699219  ...    NaN NaN  NaN NaN NaN      NaN      NaN  NaN
# 2020-01-15  29030.199219  ...    NaN NaN  NaN NaN NaN      NaN      NaN  NaN
# 2020-01-16  29297.599609  ...    NaN NaN  NaN NaN NaN      NaN      NaN  NaN
# 2020-01-17  29348.099609  ...    NaN NaN  NaN NaN NaN      NaN      NaN  NaN
# ...                  ...  ...    ...  ..  ...  ..  ..      ...      ...  ...
# 2021-03-03  31270.099609  ...    NaN NaN  NaN NaN NaN      NaN      NaN  NaN
# 2021-03-04  30924.099609  ...    NaN NaN  NaN NaN NaN      NaN      NaN  NaN
# 2021-03-05  31496.300781  ...    NaN NaN  NaN NaN NaN      NaN      NaN  NaN
# 2021-03-08  31802.400391  ...    NaN NaN  NaN NaN NaN      NaN      NaN  NaN
# 2021-03-09  31832.699219  ...    NaN NaN  NaN NaN NaN      NaN      NaN  NaN
#
# Price
# Ticker     VIX XAX
# Date
# 2020-01-13 NaN NaN
# 2020-01-14 NaN NaN
# 2020-01-15 NaN NaN
# 2020-01-16 NaN NaN
# 2020-01-17 NaN NaN
# ...         ..  ..
# 2021-03-03 NaN NaN
# 2021-03-04 NaN NaN
# 2021-03-05 NaN NaN
# 2021-03-08 NaN NaN
# 2021-03-09 NaN NaN
#
# [301 rows x 216 columns]

# %%
df.columns
# Out:
# MultiIndex([('Adj Close', '000001.SS'),
#             ('Adj Close', '399001.SZ'),
#             ('Adj Close',      'AORD'),
#             ('Adj Close',      'AXJO'),
#             ('Adj Close',       'BFX'),
#             ('Adj Close',     'BSESN'),
#             ('Adj Close',   'BUK100P'),
#             ('Adj Close',      'BVSP'),
#             ('Adj Close',    'CASE30'),
#             ('Adj Close',       'DJI'),
#             ...
#             (   'Volume',      'N225'),
#             (   'Volume',       'NYA'),
#             (   'Volume',      'NZ50'),
#             (   'Volume',       'RUT'),
#             (   'Volume',       'STI'),
#             (   'Volume',  'STOXX50E'),
#             (   'Volume',  'TA125.TA'),
#             (   'Volume',      'TWII'),
#             (   'Volume',       'VIX'),
#             (   'Volume',       'XAX')],
#            names=['Price', 'Ticker'], length=216)
